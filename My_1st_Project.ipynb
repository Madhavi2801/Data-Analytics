# %%
import numpy as np       #Helps to work with ARRAYS and for mathematical use
import pandas as pd      #Helps to work with DATAFRAMES/TABLES
import matplotlib.pyplot as plt    #To visualize data
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
d1 = pd.read_csv(r'C:\Users\MADHUINDIA\Downloads\Python_Diwali_Sales_Analysis\Diwali_data.csv', encoding= 'unicode_escape')
# To avoid encoding error, "use unicode_escape"

# %%
d1
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
d1.shape
# Out:
# (11251, 15)

# %%
d1.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
d1.tail(10)
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 11241  1003032     Matthias  P00058042      F     26-35   33               0
# 11242  1004344   Hildebrand  P00185442      F     26-35   27               1
# 11243  1005446      Sheetal  P00297742      M     51-55   53               0
# 11244  1005446      Sheetal  P00297742      M     51-55   53               0
# 11245  1004140    Bertelson  P00057442      F     26-35   31               1
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
#                 State      Zone   Occupation Product_Category  Orders  Amount  \
# ...

# %%
d1.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount  \
# count  1.125100e+04  11251.000000    11251.000000  11251.000000  11239.000000
# mean   1.003004e+06     35.421207        0.420318      2.489290   9453.610858
# std    1.716125e+03     12.754122        0.493632      1.115047   5222.355869
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      1.500000   5443.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000
#
#        Status  unnamed1
# count     0.0       0.0
# mean      NaN       NaN
# std       NaN       NaN
# min       NaN       NaN
# 25%       NaN       NaN
# 50%       NaN       NaN
# 75%       NaN       NaN
# max       NaN       NaN

# %%
d1[['Age', 'Orders', 'Amount']].describe()
# It will only describe the columns which are given
# Out:
#                 Age        Orders        Amount
# count  11251.000000  11251.000000  11239.000000
# mean      35.421207      2.489290   9453.610858
# std       12.754122      1.115047   5222.355869
# min       12.000000      1.000000    188.000000
# 25%       27.000000      1.500000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %%
d1.describe(include="all")
# Out:
#              User_ID Cust_name Product_ID Gender Age Group           Age  \
# count   1.125100e+04     11251      11251  11251     11251  11251.000000
# unique           NaN      1250       2351      2         7           NaN
# top              NaN  Vishakha  P00265242      F     26-35           NaN
# freq             NaN        42         53   7842      4543           NaN
# mean    1.003004e+06       NaN        NaN    NaN       NaN     35.421207
# std     1.716125e+03       NaN        NaN    NaN       NaN     12.754122
# min     1.000001e+06       NaN        NaN    NaN       NaN     12.000000
# 25%     1.001492e+06       NaN        NaN    NaN       NaN     27.000000
# 50%     1.003065e+06       NaN        NaN    NaN       NaN     33.000000
# 75%     1.004430e+06       NaN        NaN    NaN       NaN     43.000000
# max     1.006040e+06       NaN        NaN    NaN       NaN     92.000000
#
#         Marital_Status          State     Zone Occupation    Product_Category  \
# ...

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
d1.isnull().sum()
# OR
# pd.isnull(data).sum()
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# Status              11251
# unnamed1            11251
# dtype: int64

# %%
pd.isnull(d1)   
# This gives us the not null columns as False
# Out:
#        User_ID  Cust_name  Product_ID  Gender  Age Group    Age  \
# 0        False      False       False   False      False  False
# 1        False      False       False   False      False  False
# 2        False      False       False   False      False  False
# 3        False      False       False   False      False  False
# 4        False      False       False   False      False  False
# ...        ...        ...         ...     ...        ...    ...
# 11246    False      False       False   False      False  False
# 11247    False      False       False   False      False  False
# 11248    False      False       False   False      False  False
# 11249    False      False       False   False      False  False
# 11250    False      False       False   False      False  False
#
#        Marital_Status  State   Zone  Occupation  Product_Category  Orders  \
# 0               False  False  False       False             False   False
# ...

# %%
d1.drop(['Status', 'unnamed1'], axis=1, inplace=True)
#axis=1 -- complete row  and inplace=True -- Save whatever done in the particular line

# %%
d1
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
d1.Amount.value_counts()
# Out:
# 7907.0     11
# 7956.0     10
# 7086.0      9
# 6923.0      8
# 7037.0      8
#            ..
# 12078.0     1
# 12079.0     1
# 12082.0     1
# 12083.0     1
# 188.0       1
# Name: Amount, Length: 6584, dtype: int64

# %%
d1.Amount = d1.Amount.fillna(d1.Amount.median())

# %%
d1.Amount.value_counts()
# Out:
# 8109.0     19
# 7907.0     11
# 7956.0     10
# 7086.0      9
# 8128.0      8
#            ..
# 12078.0     1
# 12079.0     1
# 12082.0     1
# 12083.0     1
# 188.0       1
# Name: Amount, Length: 6584, dtype: int64

# %%
d1.isnull().sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
d1.dtypes
# Out:
# User_ID               int64
# Cust_name            object
# Product_ID           object
# Gender               object
# Age Group            object
# Age                   int64
# Marital_Status        int64
# State                object
# Zone                 object
# Occupation           object
# Product_Category     object
# Orders                int64
# Amount              float64
# dtype: object

# %% [markdown]
# # DTYPE conversion

# %%
d1.Gender.value_counts()
# Out:
# F    7842
# M    3409
# Name: Gender, dtype: int64

# %%
d1.Gender.replace({"F":0,"M":1},inplace=True)

# %%
d1.Gender.value_counts()
# Out:
# 0    7842
# 1    3409
# Name: Gender, dtype: int64

# %%
d1.Zone.value_counts()
# Out:
# Central     4296
# Southern    2695
# Western     1955
# Northern    1491
# Eastern      814
# Name: Zone, dtype: int64

# %%
d1.Zone.replace({"Central":1,"Northern":1,"Southern":2,"Western":3,"Eastern":4},inplace=True)

# %%
d1.Zone.value_counts()
# Out:
# 1    5787
# 2    2695
# 3    1955
# 4     814
# Name: Zone, dtype: int64

# %%
d1.rename(columns={"Age Group":"Age_Group"},inplace=True)

# %%
d1.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age_Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
d1.Age_Group.value_counts()
# Out:
# 26-35    4543
# 36-45    2286
# 18-25    1879
# 46-50     987
# 51-55     832
# 55+       428
# 0-17      296
# Name: Age_Group, dtype: int64

# %%
d1.Age_Group.replace({"0-17":0,"18-25":1,"26-35":2,"36-45":3,"46-50":4,"51-55":5,"55+":6},inplace=True)

# %%
d1.Age_Group.value_counts()
# Out:
# 2    4543
# 3    2286
# 1    1879
# 4     987
# 5     832
# 6     428
# 0     296
# Name: Age_Group, dtype: int64

# %%
d1.dtypes
# Out:
# User_ID               int64
# Cust_name            object
# Product_ID           object
# Gender                int64
# Age_Group             int64
# Age                   int64
# Marital_Status        int64
# State                object
# Zone                  int64
# Occupation           object
# Product_Category     object
# Orders                int64
# Amount              float64
# dtype: object

# %%
d1['Amount'] = d1['Amount'].astype('int')

# %%
d1.dtypes
# Out:
# User_ID              int64
# Cust_name           object
# Product_ID          object
# Gender               int64
# Age_Group            int64
# Age                  int64
# Marital_Status       int64
# State               object
# Zone                 int64
# Occupation          object
# Product_Category    object
# Orders               int64
# Amount               int32
# dtype: object

# %%
d1.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age_Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %% [markdown]
# # Outlier's Treatment

# %%
d1.boxplot(figsize=(20,10))
plt.show()

# %%
d1.boxplot(column="Age")  
plt.show()

# %%
sns.distplot(d1["Age"])
plt.show()

# %%
d1["Age"].hist()
plt.show()

# %%
d1["Age"].describe()
# Out:
# count    11251.000000
# mean        35.421207
# std         12.754122
# min         12.000000
# 25%         27.000000
# 50%         33.000000
# 75%         43.000000
# max         92.000000
# Name: Age, dtype: float64

# %%
upper_boundary=d1["Age"].mean()+3*d1["Age"].std()
lower_boundary=d1["Age"].mean()-3*d1["Age"].std()
print(upper_boundary)
print(lower_boundary)
# Out:
# 73.68357389358835
# -2.8411598859445846

# %%
d1.loc[d1["Age"]>73.68357389358835,"Age"]=73.68357389358835

# %%
d1["Age"].hist()
plt.show()

# %%
sns.distplot(d1["Age"])
plt.show()

# %%
d1.boxplot(column="Amount")  
plt.show()

# %%
sns.distplot(d1["Amount"])
plt.show()

# %%
d1["Amount"].hist()
plt.show()

# %%
d1["Amount"].describe()
# Out:
# count    11251.000000
# mean      9452.176429
# std       5219.753707
# min        188.000000
# 25%       5443.500000
# 50%       8109.000000
# 75%      12671.000000
# max      23952.000000
# Name: Amount, dtype: float64

# %%
upper_boundary1=d1["Amount"].mean()+2.5*d1["Amount"].std()
lower_boundary1=d1["Amount"].mean()-2.5*d1["Amount"].std()
print(upper_boundary1)
print(lower_boundary1)
# Out:
# 22501.560696117383
# -3597.2078385936056

# %%
d1.loc[d1["Amount"]>22502.53282362144,"Amount"]=22502.53282362144

# %%
d1["Amount"].hist()
plt.show()

# %%
sns.distplot(d1["Amount"])
plt.show()

# %% [markdown]
# # EXPLORATARY DATA ANALYSIS -- EDA

# %% [markdown]
# # Gender

# %%
d1.Gender.value_counts()
# Out:
# 0    7842
# 1    3409
# Name: Gender, dtype: int64

# %%
sns.countplot(x = 'Gender',data = d1) #here data means dataframe
# This will not give us the values
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
# This will give us the values of male and female on the particular bars
d2 = sns.countplot(x = 'Gender',data = d1)

for bars in d2.containers:
    d2.bar_label(bars)

# %%
s_gen = d1.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x = 'Gender',y = 'Amount',data = s_gen)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %% [markdown]
# From above graphs we can see that most of the buyers are females and even the purchasing power of females are greater than men

# %% [markdown]
# # Age

# %%
d1.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age_Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
d1.rename(columns = {"Age Group":"Age_Group"},inplace=True)

# %%
d1.Age_Group.value_counts()
# Out:
# 2    4543
# 3    2286
# 1    1879
# 4     987
# 5     832
# 6     428
# 0     296
# Name: Age_Group, dtype: int64

# %%
sns.countplot(x = 'Age_Group',data = d1)
# Out:
# <Axes: xlabel='Age_Group', ylabel='count'>

# %%
# HUE -- It will divide the bars with respect to gender 
sns.countplot(x = 'Age_Group',data = d1, hue = "Gender")
# Out:
# <Axes: xlabel='Age_Group', ylabel='count'>

# %%
d3 = sns.countplot(x = 'Age_Group',data = d1, hue = "Gender")

for bars in d3.containers:
    d3.bar_label(bars)

# %%
s_gen = d1.groupby(['Age_Group'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x = 'Age_Group',y = 'Amount',data = s_gen)
# Out:
# <Axes: xlabel='Age_Group', ylabel='Amount'>

# %% [markdown]
# From above graphs we can see that most of the buyers are of age group between 26-35 yrs female

# %% [markdown]
# # State

# %%
d1.State.value_counts()
# Out:
# Uttar Pradesh       1946
# Maharashtra         1526
# Karnataka           1305
# Delhi               1107
# Madhya Pradesh       923
# Andhra Pradesh       812
# Himachal Pradesh     608
# Kerala               453
# Haryana              452
# Bihar                434
# Gujarat              429
# Jharkhand            380
# Uttarakhand          320
# Rajasthan            231
# Punjab               200
# Telangana            125
# Name: State, dtype: int64

# %%
# total number of orders from top 10 states

sales_state = d1.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'State',y= 'Orders')
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
# total amount/sales from top 10 states

sales_state = d1.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'State',y= 'Amount')
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %% [markdown]
# From above graphs we can see that most of the orders & total sales/amount are from Uttar Pradesh, Maharashtra and Karnataka respectively

# %% [markdown]
# # Marital Status

# %%
d1.Marital_Status.value_counts()
# Out:
# 0    6522
# 1    4729
# Name: Marital_Status, dtype: int64

# %%
ax = sns.countplot(data = d1, x = 'Marital_Status')

sns.set(rc={'figure.figsize':(7,5)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = d1.groupby(['Marital_Status', 'Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(data = sales_state, x = 'Marital_Status',y= 'Amount', hue='Gender')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %% [markdown]
# From above graphs we can see that most of the buyers are married (women) and they have high purchasing power

# %% [markdown]
# # Occupation

# %%
d1.Occupation.value_counts()
# Out:
# IT Sector          1588
# Healthcare         1408
# Aviation           1310
# Banking            1139
# Govt                854
# Hospitality         705
# Media               637
# Automobile          566
# Chemical            542
# Lawyer              531
# Retail              501
# Food Processing     423
# Construction        414
# Textile             350
# Agriculture         283
# Name: Occupation, dtype: int64

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data = d1, x = 'Occupation')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = d1.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Occupation',y= 'Amount')
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# From above graphs we can see that most of the buyers are working in IT, Healthcare and Aviation sector

# %% [markdown]
# # Product Category

# %%
sns.set(rc={'figure.figsize':(23,5)})
ax = sns.countplot(data = d1, x = 'Product_Category')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = d1.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_Category',y= 'Amount')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %%
sales_state = d1.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_ID',y= 'Orders')
# Out:
# <Axes: xlabel='Product_ID', ylabel='Orders'>

# %%
# top 10 most sold products (same thing as above)

fig1, ax1 = plt.subplots(figsize=(12,7))
d1.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# Married women age group 26-35 yrs from UP, Maharastra and Karnataka working in IT, Healthcare and Aviation are more likely to buy products from Food, Clothing and Electronics category

# %% [markdown]
# 1. Performed data cleaning and manipulation.
# 2. Done Dtype conversion.
# 3. Performed Outlier's Treatment present in two coloumns.
# 4. Performed Exploratory Data Analysis(EDA) using pandas, matplotlib, seaborn libraries.
# 5. Improved customer experience by identifying potential customers across different States, Occupation, Gender, Age Group.
# 6. Improved Sales by identifying most selling product categories and products, which can help to plan inventory and hence meet the demands.
