# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\MADHUINDIA\Desktop\DA_Dataset\Hotel_Reservations.csv")

# %%
df
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0       INN00001             2               0                     1
# 1       INN00002             2               0                     2
# 2       INN00003             1               0                     2
# 3       INN00004             2               0                     0
# 4       INN00005             2               0                     1
# ...          ...           ...             ...                   ...
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# ...

# %%
df.head()
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  1      Not Selected                           0
#
#   room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  \
# 0        Room_Type 1        224          2017             10             2
# ...

# %%
df.tail()
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 36270                  6       Meal Plan 1                           0
# 36271                  3       Meal Plan 1                           0
# 36272                  6       Meal Plan 1                           0
# 36273                  3      Not Selected                           0
# 36274                  2       Meal Plan 1                           0
#
#       room_type_reserved  lead_time  arrival_year  arrival_month  \
# ...

# %%
df.describe()
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# count  36275.000000    36275.000000          36275.000000       36275.000000
# mean       1.844962        0.105279              0.810724           2.204300
# std        0.518715        0.402648              0.870644           1.410905
# min        0.000000        0.000000              0.000000           0.000000
# 25%        2.000000        0.000000              0.000000           1.000000
# 50%        2.000000        0.000000              1.000000           2.000000
# 75%        2.000000        0.000000              2.000000           3.000000
# max        4.000000       10.000000              7.000000          17.000000
#
#        required_car_parking_space     lead_time  arrival_year  arrival_month  \
# count                36275.000000  36275.000000  36275.000000   36275.000000
# mean                     0.030986     85.232557   2017.820427       7.423653
# ...

# %%
df.describe(include="all")
# Out:
#        Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# count       36275  36275.000000    36275.000000          36275.000000
# unique      36275           NaN             NaN                   NaN
# top      INN00001           NaN             NaN                   NaN
# freq            1           NaN             NaN                   NaN
# mean          NaN      1.844962        0.105279              0.810724
# std           NaN      0.518715        0.402648              0.870644
# min           NaN      0.000000        0.000000              0.000000
# 25%           NaN      2.000000        0.000000              0.000000
# 50%           NaN      2.000000        0.000000              1.000000
# 75%           NaN      2.000000        0.000000              2.000000
# max           NaN      4.000000       10.000000              7.000000
#
#         no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# ...

# %%
df.shape
# Out:
# (36275, 19)

# %%
df.nunique()
# Out:
# Booking_ID                              36275
# no_of_adults                                5
# no_of_children                              6
# no_of_weekend_nights                        8
# no_of_week_nights                          18
# type_of_meal_plan                           4
# required_car_parking_space                  2
# room_type_reserved                          7
# lead_time                                 352
# arrival_year                                2
# arrival_month                              12
# arrival_date                               31
# market_segment_type                         5
# repeated_guest                              2
# no_of_previous_cancellations                9
# no_of_previous_bookings_not_canceled       59
# avg_price_per_room                       3930
# no_of_special_requests                      6
# booking_status                              2
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Booking_ID                              0
# no_of_adults                            0
# no_of_children                          0
# no_of_weekend_nights                    0
# no_of_week_nights                       0
# type_of_meal_plan                       0
# required_car_parking_space              0
# room_type_reserved                      0
# lead_time                               0
# arrival_year                            0
# arrival_month                           0
# arrival_date                            0
# market_segment_type                     0
# repeated_guest                          0
# no_of_previous_cancellations            0
# no_of_previous_bookings_not_canceled    0
# avg_price_per_room                      0
# no_of_special_requests                  0
# booking_status                          0
# dtype: int64

# %% [markdown]
# Data is already cleaned so there is no need to perform any data cleaning technique

# %%
df.dtypes
# Out:
# Booking_ID                               object
# no_of_adults                              int64
# no_of_children                            int64
# no_of_weekend_nights                      int64
# no_of_week_nights                         int64
# type_of_meal_plan                        object
# required_car_parking_space                int64
# room_type_reserved                       object
# lead_time                                 int64
# arrival_year                              int64
# arrival_month                             int64
# arrival_date                              int64
# market_segment_type                      object
# repeated_guest                            int64
# no_of_previous_cancellations              int64
# no_of_previous_bookings_not_canceled      int64
# avg_price_per_room                      float64
# no_of_special_requests                    int64
# booking_status                           object
# dtype: object

# %%
df.columns
# Out:
# Index(['Booking_ID', 'no_of_adults', 'no_of_children', 'no_of_weekend_nights',
#        'no_of_week_nights', 'type_of_meal_plan', 'required_car_parking_space',
#        'room_type_reserved', 'lead_time', 'arrival_year', 'arrival_month',
#        'arrival_date', 'market_segment_type', 'repeated_guest',
#        'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled',
#        'avg_price_per_room', 'no_of_special_requests', 'booking_status'],
#       dtype='object')

# %% [markdown]
# #### Dropping Unwanted columns

# %%
B_ID = df["Booking_ID"]
df = df.drop(["Booking_ID"],axis = 1)

# %% [markdown]
# ## D-Type Conversion

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %% [markdown]
# #### Column - type_of_meal_plan

# %%
df.type_of_meal_plan.value_counts()
# Out:
# Meal Plan 1     27835
# Not Selected     5130
# Meal Plan 2      3305
# Meal Plan 3         5
# Name: type_of_meal_plan, dtype: int64

# %%
df.type_of_meal_plan = le.fit_transform(df.type_of_meal_plan)

# %%
df.type_of_meal_plan.value_counts()
# Out:
# 0    27835
# 3     5130
# 1     3305
# 2        5
# Name: type_of_meal_plan, dtype: int64

# %% [markdown]
# #### Column - room_type_reserved

# %%
df.room_type_reserved.value_counts()
# Out:
# Room_Type 1    28130
# Room_Type 4     6057
# Room_Type 6      966
# Room_Type 2      692
# Room_Type 5      265
# Room_Type 7      158
# Room_Type 3        7
# Name: room_type_reserved, dtype: int64

# %%
df.room_type_reserved = le.fit_transform(df.room_type_reserved)

# %%
df.room_type_reserved.value_counts()
# Out:
# 0    28130
# 3     6057
# 5      966
# 1      692
# 4      265
# 6      158
# 2        7
# Name: room_type_reserved, dtype: int64

# %% [markdown]
# #### Column - market_segment_type

# %%
df.market_segment_type.value_counts()
# Out:
# Online           23214
# Offline          10528
# Corporate         2017
# Complementary      391
# Aviation           125
# Name: market_segment_type, dtype: int64

# %%
df.market_segment_type = le.fit_transform(df.market_segment_type)

# %%
df.market_segment_type.value_counts()
# Out:
# 4    23214
# 3    10528
# 2     2017
# 1      391
# 0      125
# Name: market_segment_type, dtype: int64

# %% [markdown]
# #### Column - booking_status

# %%
df.booking_status.value_counts()
# Out:
# Not_Canceled    24390
# Canceled        11885
# Name: booking_status, dtype: int64

# %%
df.booking_status = le.fit_transform(df.booking_status)

# %%
df.booking_status.value_counts()
# Out:
# 1    24390
# 0    11885
# Name: booking_status, dtype: int64

# %%
df.dtypes
# Out:
# no_of_adults                              int64
# no_of_children                            int64
# no_of_weekend_nights                      int64
# no_of_week_nights                         int64
# type_of_meal_plan                         int32
# required_car_parking_space                int64
# room_type_reserved                        int32
# lead_time                                 int64
# arrival_year                              int64
# arrival_month                             int64
# arrival_date                              int64
# market_segment_type                       int32
# repeated_guest                            int64
# no_of_previous_cancellations              int64
# no_of_previous_bookings_not_canceled      int64
# avg_price_per_room                      float64
# no_of_special_requests                    int64
# booking_status                            int32
# dtype: object

# %% [markdown]
# Data is cleaned, no null values present, and all columns are converted into numeric datatype.

# %% [markdown]
# # BASE MODEL

# %%
df.head()
# Out:
#    no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0             2               0                     1                  2
# 1             2               0                     2                  3
# 2             1               0                     2                  1
# 3             2               0                     0                  2
# 4             2               0                     1                  1
#
#    type_of_meal_plan  required_car_parking_space  room_type_reserved  \
# 0                  0                           0                   0
# 1                  3                           0                   0
# 2                  0                           0                   0
# 3                  0                           0                   0
# 4                  3                           0                   0
#
#    lead_time  arrival_year  arrival_month  arrival_date  market_segment_type  \
# ...

# %% [markdown]
# ## Splitting the data

# %%
x=df.iloc[:,:-1] 
x.head(2)
# Out:
#    no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0             2               0                     1                  2
# 1             2               0                     2                  3
#
#    type_of_meal_plan  required_car_parking_space  room_type_reserved  \
# 0                  0                           0                   0
# 1                  3                           0                   0
#
#    lead_time  arrival_year  arrival_month  arrival_date  market_segment_type  \
# 0        224          2017             10             2                    3
# 1          5          2018             11             6                    4
#
#    repeated_guest  no_of_previous_cancellations  \
# 0               0                             0
# 1               0                             0
#
#    no_of_previous_bookings_not_canceled  avg_price_per_room  \
# 0                                     0               65.00
# ...

# %%
y=df.iloc[:,-1] 
y.head(2)
# Out:
# 0    1
# 1    1
# Name: booking_status, dtype: int32

# %%
import sklearn
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest= train_test_split(x,y,test_size=0.2,random_state=101)

# %%
xtrain.shape,xtest.shape,ytrain.shape,ytest.shape
# Out:
# ((29020, 17), (7255, 17), (29020,), (7255,))

# %% [markdown]
# ## 1. Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lg=LogisticRegression()

# %%
lg.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
p=lg.predict(xtest)
p
# Out:
# array([1, 1, 1, ..., 1, 1, 0])

# %%
prob=lg.predict_proba(xtest)
prob
# Out:
# array([[0.08380387, 0.91619613],
#        [0.03044813, 0.96955187],
#        [0.0149899 , 0.9850101 ],
#        ...,
#        [0.00362654, 0.99637346],
#        [0.45837074, 0.54162926],
#        [0.74831253, 0.25168747]])

# %%
from sklearn.metrics import confusion_matrix

# %%
l_cm=confusion_matrix(p,ytest)
l_cm
# Out:
# array([[1341,  498],
#        [1023, 4393]], dtype=int64)

# %%
l_acc=l_cm.diagonal().sum()/l_cm.sum()*100
l_acc
# Out:
# 79.03514817367333

# %%
from sklearn.metrics import classification_report
print(classification_report(p,ytest))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.73      0.64      1839
#            1       0.90      0.81      0.85      5416
#
#     accuracy                           0.79      7255
#    macro avg       0.73      0.77      0.75      7255
# weighted avg       0.81      0.79      0.80      7255

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

blg_precision = precision_score(ytest,p)
print('Precisiom: %f' % blg_precision)

# Recall :- tp / (tp+fn)

blg_recall = recall_score(ytest,p)
print('Recall: %f' % blg_recall)

#f1 :- 2tp / (2tp + fp + fn)

blg_f1 = f1_score(ytest,p)
print('F1 score: %f' % blg_f1)
# Out:
# Precisiom: 0.811115
# Recall: 0.898180
# F1 score: 0.852430

# %%
df1=pd.DataFrame(prob)
df1
# Out:
#              0         1
# 0     0.083804  0.916196
# 1     0.030448  0.969552
# 2     0.014990  0.985010
# 3     0.451897  0.548103
# 4     0.268411  0.731589
# ...        ...       ...
# 7250  0.118466  0.881534
# 7251  0.516459  0.483541
# 7252  0.003627  0.996373
# 7253  0.458371  0.541629
# 7254  0.748313  0.251687
#
# [7255 rows x 2 columns]

# %%
df_final=df1.rename(columns={df1.columns[1]:"Yes"})
df_final
# Out:
#              0       Yes
# 0     0.083804  0.916196
# 1     0.030448  0.969552
# 2     0.014990  0.985010
# 3     0.451897  0.548103
# 4     0.268411  0.731589
# ...        ...       ...
# 7250  0.118466  0.881534
# 7251  0.516459  0.483541
# 7252  0.003627  0.996373
# 7253  0.458371  0.541629
# 7254  0.748313  0.251687
#
# [7255 rows x 2 columns]

# %% [markdown]
# ## AUC ROC Curve

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# %%
roc=roc_auc_score(ytest,df1.iloc[:,1])
roc
# Out:
# 0.8455384488447132

# %%
fpr,tpr,threshold=roc_curve(ytest,df1.iloc[:,1])

# %%
plt.plot(fpr,tpr)
plt.show()

# %% [markdown]
# ## Precision Recall Curve

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score

# %%
precision,recall,thresold=precision_recall_curve(ytest,df1.iloc[:,1])

# %%
plt.plot(recall,precision,label="PRC-Curve")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.legend(loc="upper left")
plt.title("PRC-Curve")
plt.show()

# %% [markdown]
# ## 2. Decison Tree

# %%
from sklearn.tree import DecisionTreeClassifier 
dt=DecisionTreeClassifier()

# %%
dt.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
dt_p=dt.predict(xtest)
dt_p
# Out:
# array([1, 1, 1, ..., 1, 0, 1])

# %%
dt.feature_importances_
# Out:
# array([2.89040794e-02, 5.35139738e-03, 3.39633707e-02, 4.66375232e-02,
#        1.29066258e-02, 7.27433577e-03, 9.87898280e-03, 3.50115694e-01,
#        1.24220219e-02, 7.00975754e-02, 8.13741823e-02, 9.97460317e-02,
#        4.45514661e-04, 3.85764062e-04, 3.03976775e-04, 1.70897623e-01,
#        6.92953016e-02])

# %%
dt_cf=confusion_matrix(dt_p,ytest)
dt_cf
# Out:
# array([[1915,  481],
#        [ 449, 4410]], dtype=int64)

# %%
dt_acc=dt_cf.diagonal().sum()/dt_cf.sum()*100
dt_acc
# Out:
# 87.18125430737422

# %%
print(classification_report(dt_p,ytest))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.80      0.80      2396
#            1       0.90      0.91      0.90      4859
#
#     accuracy                           0.87      7255
#    macro avg       0.86      0.85      0.85      7255
# weighted avg       0.87      0.87      0.87      7255

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

bdt_precision = precision_score(ytest,dt_p)
print('Precisiom: %f' % bdt_precision)

# Recall :- tp / (tp+fn)

bdt_recall = recall_score(ytest, dt_p)
print('Recall: %f' % bdt_recall)

#f1 :- 2tp / (2tp + fp + fn)

bdt_f1 = f1_score(ytest,dt_p)
print('F1 score: %f' % bdt_f1)
# Out:
# Precisiom: 0.907594
# Recall: 0.901656
# F1 score: 0.904615

# %% [markdown]
# ## 3. Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()

# %%
rf.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
rf_p=rf.predict(xtest)
rf_p
# Out:
# array([1, 1, 1, ..., 1, 0, 1])

# %%
rf_cf=confusion_matrix(rf_p,ytest)
rf_cf
# Out:
# array([[1937,  263],
#        [ 427, 4628]], dtype=int64)

# %%
rf_acc=rf_cf.diagonal().sum()/rf_cf.sum()*100
rf_acc
# Out:
# 90.48931771192281

# %%
print(classification_report(rf_p,ytest))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85      2200
#            1       0.95      0.92      0.93      5055
#
#     accuracy                           0.90      7255
#    macro avg       0.88      0.90      0.89      7255
# weighted avg       0.91      0.90      0.91      7255

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

brf_precision = precision_score(ytest,rf_p)
print('Precisiom: %f' % brf_precision)

# Recall :- tp / (tp+fn)

brf_recall = recall_score(ytest, rf_p)
print('Recall: %f' % brf_recall)

#f1 :- 2tp / (2tp + fp + fn)

brf_f1 = f1_score(ytest,rf_p)
print('F1 score: %f' % brf_f1)
# Out:
# Precisiom: 0.915529
# Recall: 0.946228
# F1 score: 0.930625

# %% [markdown]
# ## 4. K-Nearest Neighbor

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=17)

# %%
knn.fit(xtrain,ytrain)
# Out:
# KNeighborsClassifier(n_neighbors=17)

# %%
knn_p=knn.predict(xtest)
knn_p
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
knn_cf=confusion_matrix(knn_p,ytest)
knn_cf
# Out:
# array([[1323,  366],
#        [1041, 4525]], dtype=int64)

# %%
knn_acc=knn_cf.diagonal().sum()/knn_cf.sum()*100
knn_acc
# Out:
# 80.6064782908339

# %%
print(classification_report(knn_p,ytest))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.56      0.78      0.65      1689
#            1       0.93      0.81      0.87      5566
#
#     accuracy                           0.81      7255
#    macro avg       0.74      0.80      0.76      7255
# weighted avg       0.84      0.81      0.82      7255

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

bkn_precision = precision_score(ytest,knn_p)
print('Precisiom: %f' % bkn_precision)

# Recall :- tp / (tp+fn)

bkn_recall = recall_score(ytest, knn_p)
print('Recall: %f' % bkn_recall)

#f1 :- 2tp / (2tp + fp + fn)

bkn_f1 = f1_score(ytest,knn_p)
print('F1 score: %f' % bkn_f1)
# Out:
# Precisiom: 0.812972
# Recall: 0.925169
# F1 score: 0.865449

# %% [markdown]
# ## 5. Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
nb=MultinomialNB()

# %%
nb.fit(xtrain,ytrain)
# Out:
# MultinomialNB()

# %%
nb_p=nb.predict(xtest)
nb_p
# Out:
# array([1, 1, 1, ..., 1, 1, 0])

# %%
nb_m=confusion_matrix(nb_p,ytest)
nb_m
# Out:
# array([[1436, 1066],
#        [ 928, 3825]], dtype=int64)

# %%
nb_acc=nb_m.diagonal().sum()/nb_m.sum()*100
nb_acc
# Out:
# 72.51550654720882

# %%
print(classification_report(nb_p,ytest))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.57      0.59      2502
#            1       0.78      0.80      0.79      4753
#
#     accuracy                           0.73      7255
#    macro avg       0.69      0.69      0.69      7255
# weighted avg       0.72      0.73      0.72      7255

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

bnb_precision = precision_score(ytest,nb_p)
print('Precisiom: %f' % bnb_precision)

# Recall :- tp / (tp+fn)

bnb_recall = recall_score(ytest, nb_p)
print('Recall: %f' % bnb_recall)

#f1 :- 2tp / (2tp + fp + fn)

bnb_f1 = f1_score(ytest,nb_p)
print('F1 score: %f' % bnb_f1)
# Out:
# Precisiom: 0.804755
# Recall: 0.782049
# F1 score: 0.793239

# %% [markdown]
# ## 6. XGBOOST

# %%
from xgboost import XGBClassifier
xgb=XGBClassifier()

# %%
xgb.fit(xtrain,ytrain)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
xgb_p=xgb.predict(xtest)
xgb_p
# Out:
# array([1, 1, 1, ..., 1, 0, 1])

# %%
xgb_m=confusion_matrix(xgb_p,ytest)
xgb_m
# Out:
# array([[1907,  290],
#        [ 457, 4601]], dtype=int64)

# %%
xgb_acc=xgb_m.diagonal().sum()/xgb_m.sum()*100
xgb_acc
# Out:
# 89.70365265334253

# %%
print(classification_report(xgb_p,ytest))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.87      0.84      2197
#            1       0.94      0.91      0.92      5058
#
#     accuracy                           0.90      7255
#    macro avg       0.87      0.89      0.88      7255
# weighted avg       0.90      0.90      0.90      7255

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

bxgb_precision = precision_score(ytest,xgb_p)
print('Precisiom: %f' % bxgb_precision)

# Recall :- tp / (tp+fn)

bxgb_recall = recall_score(ytest, xgb_p)
print('Recall: %f' % bxgb_recall)

#f1 :- 2tp / (2tp + fp + fn)

bxgb_f1 = f1_score(ytest,xgb_p)
print('F1 score: %f' % bxgb_f1)
# Out:
# Precisiom: 0.909648
# Recall: 0.940707
# F1 score: 0.924917

# %%
list1 = {
    "Logistic_Regression":l_acc,
    "Decision_Tree":dt_acc,
    "Random_forest":rf_acc,
    "K-Nearest Neighbor":knn_acc,
    "Naive_Bayes":nb_acc,
    "XGBoost":xgb_acc
}

list2 = {
    "Logistic_Regression":blg_precision,
    "Decision_Tree":bdt_precision,
    "Random_forest":brf_precision,
    "K-Nearest Neighbor":bkn_precision,
    "Naive_Bayes":bnb_precision,
    "XGBoost":bxgb_precision
}

list3 = {
    "Logistic_Regression":blg_recall,
    "Decision_Tree":bdt_recall,
    "Random_forest":brf_recall,
    "K-Nearest Neighbor":bkn_recall,
    "Naive_Bayes":bnb_recall,
    "XGBoost":bxgb_recall
}

list4 = {
    "Logistic_Regression":blg_f1,
    "Decision_Tree":bdt_f1,
    "Random_forest":brf_f1 ,
    "K-Nearest Neighbor":bkn_f1,
    "Naive_Bayes":bnb_f1,
    "XGBoost":bxgb_f1

}

# %%
Base_Model =pd.DataFrame({'Accuracy':list1, 'Precision':list2, 'Recall':list3, 'f1 score': list4})
Base_Model.style.set_caption("Base model metrics")
# Out:
# <style type="text/css">
# </style>
# <table id="T_a995c">
#   <caption>Base model metrics</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a995c_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_a995c_level0_col1" class="col_heading level0 col1" >Precision</th>
#       <th id="T_a995c_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_a995c_level0_col3" class="col_heading level0 col3" >f1 score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a995c_level0_row0" class="row_heading level0 row0" >Logistic_Regression</th>
#       <td id="T_a995c_row0_col0" class="data row0 col0" >79.035148</td>
#       <td id="T_a995c_row0_col1" class="data row0 col1" >0.811115</td>
#       <td id="T_a995c_row0_col2" class="data row0 col2" >0.898180</td>
#       <td id="T_a995c_row0_col3" class="data row0 col3" >0.852430</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# # EDA - Exploratory Data Analysis

# %%
df.columns
# Out:
# Index(['no_of_adults', 'no_of_children', 'no_of_weekend_nights',
#        'no_of_week_nights', 'type_of_meal_plan', 'required_car_parking_space',
#        'room_type_reserved', 'lead_time', 'arrival_year', 'arrival_month',
#        'arrival_date', 'market_segment_type', 'repeated_guest',
#        'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled',
#        'avg_price_per_room', 'no_of_special_requests', 'booking_status'],
#       dtype='object')

# %%
sns.scatterplot(x='lead_time', y='avg_price_per_room', data=df, hue='booking_status')
# Out:
# <Axes: xlabel='lead_time', ylabel='avg_price_per_room'>

# %%
sns.barplot(x="type_of_meal_plan", y='booking_status', data=df)
# Out:
# <Axes: xlabel='type_of_meal_plan', ylabel='booking_status'>

# %%
sns.countplot(data=df, x='booking_status', hue='repeated_guest')
# Out:
# <Axes: xlabel='booking_status', ylabel='count'>

# %%
sns.countplot(data=df, x='market_segment_type', hue='repeated_guest')
# Out:
# <Axes: xlabel='market_segment_type', ylabel='count'>

# %%
sns.countplot(data=df, x='no_of_special_requests', hue='booking_status')
# Out:
# <Axes: xlabel='no_of_special_requests', ylabel='count'>

# %%
sns.histplot(data=df,x="lead_time",hue="booking_status",multiple="stack")
# Out:
# <Axes: xlabel='lead_time', ylabel='Count'>

# %%
sns.kdeplot(data=df,x="arrival_year",hue="booking_status",multiple="stack")
# Out:
# <Axes: xlabel='arrival_year', ylabel='Density'>

# %% [markdown]
# # Class Imbalance

# %%
df.booking_status.value_counts()
# Out:
# 1    24390
# 0    11885
# Name: booking_status, dtype: int64

# %%
sns.countplot(x = "booking_status", data=df)
# Out:
# <Axes: xlabel='booking_status', ylabel='count'>

# %% [markdown]
# From this graph we can see that the model is biased where 1 is high while 0 is less.

# %%
df.head()
# Out:
#    no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0             2               0                     1                  2
# 1             2               0                     2                  3
# 2             1               0                     2                  1
# 3             2               0                     0                  2
# 4             2               0                     1                  1
#
#    type_of_meal_plan  required_car_parking_space  room_type_reserved  \
# 0                  0                           0                   0
# 1                  3                           0                   0
# 2                  0                           0                   0
# 3                  0                           0                   0
# 4                  3                           0                   0
#
#    lead_time  arrival_year  arrival_month  arrival_date  market_segment_type  \
# ...

# %% [markdown]
# # IMB OVER SAMPLING

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
X=df.iloc[:,:-1]
Y=df.iloc[:,-1]

# %%
df.booking_status.value_counts()
# Out:
# 1    24390
# 0    11885
# Name: booking_status, dtype: int64

# %%
ros=RandomOverSampler(random_state=42)
x1,y1=ros.fit_resample(X,Y)

# %%
x1.shape,y1.shape
# Out:
# ((48780, 17), (48780,))

# %%
y1.value_counts()
# Out:
# 1    24390
# 0    24390
# Name: booking_status, dtype: int64

# %%
x_tr,x_te,y_tr,y_te = train_test_split(x1,y1,test_size=0.2,random_state=101)

# %%
x_tr.shape,x_te.shape,y_tr.shape,y_te.shape
# Out:
# ((39024, 17), (9756, 17), (39024,), (9756,))

# %% [markdown]
# ## 1. Logistic Regression - IMB

# %%
lg.fit(x_tr,y_tr)
# Out:
# LogisticRegression()

# %%
imb_p = lg.predict(x_te)
imb_p
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
imb_cf = confusion_matrix(imb_p,y_te)
imb_cf
# Out:
# array([[3715, 1030],
#        [1132, 3879]], dtype=int64)

# %%
imb_ac = imb_cf.diagonal().sum()/imb_cf.sum()*100
imb_ac
# Out:
# 77.83927839278392

# %%
print(classification_report(imb_p,y_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.78      0.77      4745
#            1       0.79      0.77      0.78      5011
#
#     accuracy                           0.78      9756
#    macro avg       0.78      0.78      0.78      9756
# weighted avg       0.78      0.78      0.78      9756

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

ilg_precision = precision_score(y_te,imb_p)
print('Precisiom: %f' % ilg_precision)

# Recall :- tp / (tp+fn)

ilg_recall = recall_score(y_te, imb_p)
print('Recall: %f' % ilg_recall)

#f1 :- 2tp / (2tp + fp + fn)

ilg_f1 = f1_score(y_te,imb_p)
print('F1 score: %f' % ilg_f1)
# Out:
# Precisiom: 0.774097
# Recall: 0.790181
# F1 score: 0.782056

# %% [markdown]
# ## 2. Decision Tree - IMB

# %%
dt.fit(x_tr,y_tr)
# Out:
# DecisionTreeClassifier()

# %%
imb_p1 = dt.predict(x_te)
imb_p1
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
idt_cf = confusion_matrix(imb_p1,y_te)
idt_cf
# Out:
# array([[4600,  555],
#        [ 247, 4354]], dtype=int64)

# %%
idt_ac = idt_cf.diagonal().sum()/idt_cf.sum()*100
idt_ac
# Out:
# 91.77941779417795

# %%
print(classification_report(imb_p1,y_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.89      0.92      5155
#            1       0.89      0.95      0.92      4601
#
#     accuracy                           0.92      9756
#    macro avg       0.92      0.92      0.92      9756
# weighted avg       0.92      0.92      0.92      9756

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

idt_precision = precision_score(y_te, imb_p1)
print('Precisiom: %f' % idt_precision)

# Recall :- tp / (tp+fn)

idt_recall = recall_score(y_te, imb_p1)
print('Recall: %f' % idt_recall)

#f1 :- 2tp / (2tp + fp + fn)

idt_f1 = f1_score(y_te, imb_p1)
print('F1 score: %f' % idt_f1)
# Out:
# Precisiom: 0.946316
# Recall: 0.886942
# F1 score: 0.915668

# %% [markdown]
# ## 3. Random Forest - IMB

# %%
rf.fit(x_tr,y_tr)
# Out:
# RandomForestClassifier()

# %%
imb_p2 = rf.predict(x_te)
imb_p2
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
irf_cf = confusion_matrix(imb_p2,y_te)
irf_cf
# Out:
# array([[4627,  350],
#        [ 220, 4559]], dtype=int64)

# %%
irf_ac = irf_cf.diagonal().sum()/irf_cf.sum()*100
irf_ac
# Out:
# 94.15744157441574

# %%
print(classification_report(imb_p2,y_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94      4977
#            1       0.93      0.95      0.94      4779
#
#     accuracy                           0.94      9756
#    macro avg       0.94      0.94      0.94      9756
# weighted avg       0.94      0.94      0.94      9756

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

irf_precision = precision_score(y_te,imb_p2)
print('Precisiom: %f' % irf_precision)

# Recall :- tp / (tp+fn)

irf_recall = recall_score(y_te, imb_p2)
print('Recall: %f' % irf_recall)

#f1 :- 2tp / (2tp + fp + fn)

irf_f1 = f1_score(y_te,imb_p2)
print('F1 score: %f' % irf_f1)
# Out:
# Precisiom: 0.953965
# Recall: 0.928702
# F1 score: 0.941164

# %% [markdown]
# ## 4. KNN- IMB

# %%
knn.fit(x_tr,y_tr)
# Out:
# KNeighborsClassifier(n_neighbors=17)

# %%
imb_p3 = knn.predict(x_te)
imb_p3
# Out:
# array([0, 1, 0, ..., 1, 0, 0])

# %%
iknn_cf = confusion_matrix(imb_p3,y_te)
iknn_cf
# Out:
# array([[3760, 1033],
#        [1087, 3876]], dtype=int64)

# %%
iknn_ac = iknn_cf.diagonal().sum()/iknn_cf.sum()*100
iknn_ac
# Out:
# 78.26978269782697

# %%
print(classification_report(imb_p3,y_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.78      0.78      4793
#            1       0.79      0.78      0.79      4963
#
#     accuracy                           0.78      9756
#    macro avg       0.78      0.78      0.78      9756
# weighted avg       0.78      0.78      0.78      9756

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

iknn_precision = precision_score(y_te,imb_p3)
print('Precisiom: %f' % iknn_precision)

# Recall :- tp / (tp+fn)

iknn_recall = recall_score(y_te, imb_p3)
print('Recall: %f' % iknn_recall)

#f1 :- 2tp / (2tp + fp + fn)

iknn_f1 = f1_score(y_te,imb_p3)
print('F1 score: %f' % iknn_f1)
# Out:
# Precisiom: 0.780979
# Recall: 0.789570
# F1 score: 0.785251

# %% [markdown]
# ## 5. Naive Bayes - IMB

# %%
nb.fit(x_tr,y_tr)
# Out:
# MultinomialNB()

# %%
imb_p5 = nb.predict(x_te)

# %%
inb_cf = confusion_matrix(imb_p5,y_te)
inb_cf
# Out:
# array([[3024, 1000],
#        [1823, 3909]], dtype=int64)

# %%
inb_ac = inb_cf.diagonal().sum()/inb_cf.sum()*100
inb_ac
# Out:
# 71.06396063960639

# %%
print(classification_report(imb_p5,y_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.75      0.68      4024
#            1       0.80      0.68      0.73      5732
#
#     accuracy                           0.71      9756
#    macro avg       0.71      0.72      0.71      9756
# weighted avg       0.73      0.71      0.71      9756

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

inb_precision = precision_score(y_te,imb_p5)
print('Precisiom: %f' % inb_precision)

# Recall :- tp / (tp+fn)

inb_recall = recall_score(y_te, imb_p5)
print('Recall: %f' % inb_recall)

#f1 :- 2tp / (2tp + fp + fn)

inb_f1 = f1_score(y_te,imb_p5)
print('F1 score: %f' % inb_f1)
# Out:
# Precisiom: 0.681961
# Recall: 0.796293
# F1 score: 0.734705

# %% [markdown]
# ## 6. XGBOOST - IMB

# %%
xgb.fit(x_tr,y_tr)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
imb_p6 = xgb.predict(x_te)
imb_p6
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
ixgb_cf = confusion_matrix(imb_p6,y_te)
ixgb_cf
# Out:
# array([[4359,  517],
#        [ 488, 4392]], dtype=int64)

# %%
ixgb_ac = ixgb_cf.diagonal().sum()/ixgb_cf.sum()*100
ixgb_ac
# Out:
# 89.69864698646987

# %%
print(classification_report(imb_p6,y_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.89      0.90      4876
#            1       0.89      0.90      0.90      4880
#
#     accuracy                           0.90      9756
#    macro avg       0.90      0.90      0.90      9756
# weighted avg       0.90      0.90      0.90      9756

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

ixgb_precision = precision_score(y_te,imb_p6)
print('Precisiom: %f' % ixgb_precision)

# Recall :- tp / (tp+fn)

ixgb_recall = recall_score(y_te, imb_p6)
print('Recall: %f' % ixgb_recall)

#f1 :- 2tp / (2tp + fp + fn)

ixgb_f1 = f1_score(y_te,imb_p6)
print('F1 score: %f' % ixgb_f1)
# Out:
# Precisiom: 0.900000
# Recall: 0.894683
# F1 score: 0.897334

# %% [markdown]
# # Comparison

# %%
list1 = ['LG','DT','RF','KNN','NB','XGB']
list2 = [l_acc,dt_acc,rf_acc,knn_acc,nb_acc,xgb_acc]
IMB = ['LG','DT','RF','KNN','NB','XGB']
IMB1 = [imb_ac,idt_ac,irf_ac,iknn_ac,inb_ac,ixgb_ac]

# %%
result  = pd.DataFrame({'Base model name': list1,'accuracy_base':list2, 'IMB name':IMB, 'accuracy_IMB':IMB1})
result
# Out:
#   Base model name  accuracy_base IMB name  accuracy_IMB
# 0              LG      79.035148       LG     77.839278
# 1              DT      87.181254       DT     91.779418
# 2              RF      90.489318       RF     94.157442
# 3             KNN      80.606478      KNN     78.269783
# 4              NB      72.515507       NB     71.063961
# 5             XGB      89.703653      XGB     89.698647

# %% [markdown]
# ## Checking for Correlation

# %%
df_cor=df.corr()
df_cor
# Out:
#                                       no_of_adults  no_of_children  \
# no_of_adults                              1.000000       -0.019787
# no_of_children                           -0.019787        1.000000
# no_of_weekend_nights                      0.103316        0.029478
# no_of_week_nights                         0.105622        0.024398
# type_of_meal_plan                         0.025555       -0.086764
# required_car_parking_space                0.011429        0.034244
# room_type_reserved                        0.270348        0.364073
# lead_time                                 0.097287       -0.047091
# arrival_year                              0.076719        0.045983
# arrival_month                             0.021841       -0.003076
# arrival_date                              0.026338        0.025482
# market_segment_type                       0.314103        0.130618
# repeated_guest                           -0.192277       -0.036348
# ...

# %%
plt.figure(figsize=(15,10))
heatmap=sns.heatmap(df_cor,linewidth=1,annot=True,cmap=plt.cm.Reds)
plt.title("Heatmap")
plt.show()

# %% [markdown]
# # Checking For Outlier's

# %% [markdown]
# ### no_of_week_nights

# %%
df.boxplot(figsize=(20,10))
plt.show()

# %%
df.skew()
# Out:
# no_of_adults                            -0.333295
# no_of_children                           4.710350
# no_of_weekend_nights                     0.737616
# no_of_week_nights                        1.599350
# type_of_meal_plan                        1.801398
# required_car_parking_space               5.413643
# room_type_reserved                       1.729018
# lead_time                                1.292492
# arrival_year                            -1.669695
# arrival_month                           -0.348229
# arrival_date                             0.028809
# market_segment_type                     -1.684871
# repeated_guest                           6.002888
# no_of_previous_cancellations            25.199876
# no_of_previous_bookings_not_canceled    19.250191
# avg_price_per_room                       0.667133
# no_of_special_requests                   1.145081
# booking_status                          -0.734507
# dtype: float64

# %%
df.boxplot(column="no_of_week_nights")
plt.show()

# %%
sns.distplot(df.no_of_week_nights,bins=10)
plt.show()

# %%
df.no_of_week_nights.hist()
plt.show()

# %%
df.no_of_week_nights.skew()
# Out:
# 1.5993503651924639

# %%
df.no_of_week_nights.describe()
# Out:
# count    36275.000000
# mean         2.204300
# std          1.410905
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         17.000000
# Name: no_of_week_nights, dtype: float64

# %%
IQR_WN=df.no_of_week_nights.quantile(0.75)-df.no_of_week_nights.quantile(0.25)
IQR_WN
# Out:
# 2.0

# %%
u_b=df["no_of_week_nights"].quantile(0.75)+(IQR_WN*3)  
print(u_b)
# Out:
# 9.0

# %%
df[(df["no_of_week_nights"] > 9.0 )]
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 194               2               0                     4                 10
# 380               2               0                     4                 11
# 539               1               0                     6                 15
# 732               2               2                     4                 10
# 1588              1               0                     6                 13
# ...             ...             ...                   ...                ...
# 35407             3               0                     5                 10
# 35449             2               0                     4                 10
# 35778             3               0                     4                 10
# 35904             2               2                     4                 10
# 36163             1               0                     6                 13
#
# ...

# %%
df.loc[df["no_of_week_nights"]>9.0,"no_of_week_nights"]=9.0

# %%
df.no_of_week_nights.skew()
# Out:
# 1.0623042006090033

# %%
sns.distplot(df.no_of_week_nights,bins=10)
plt.show()

# %%
df.no_of_week_nights.hist()
plt.show()

# %% [markdown]
# ### lead_time

# %%
sns.distplot(df.lead_time,bins=10)
plt.show()

# %%
df.lead_time.hist()
plt.show()

# %%
df.lead_time.skew()
# Out:
# 1.2924915330710838

# %%
df.lead_time.describe()
# Out:
# count    36275.000000
# mean        85.232557
# std         85.930817
# min          0.000000
# 25%         17.000000
# 50%         57.000000
# 75%        126.000000
# max        443.000000
# Name: lead_time, dtype: float64

# %%
IQR_LT=df.lead_time.quantile(0.75)-df.lead_time.quantile(0.25)
IQR_LT
# Out:
# 109.0

# %%
u_b1=df["lead_time"].quantile(0.75)+(IQR_LT*3)  
print(u_b1)
# Out:
# 453.0

# %%
df.loc[df["lead_time"]>453.0,"lead_time"]=453.0

# %%
df.lead_time.skew()
# Out:
# 1.2924915330710838

# %%
sns.distplot(df.lead_time,bins=10)
plt.show()

# %%
df.lead_time.hist()
plt.show()

# %% [markdown]
# ### avg_price_per_room

# %%
df.boxplot(column="avg_price_per_room")
plt.show()

# %%
sns.distplot(df.avg_price_per_room,bins=10)
plt.show()

# %%
df.avg_price_per_room.hist()
plt.show()

# %%
df.avg_price_per_room.skew()
# Out:
# 0.6671328746979995

# %%
df.avg_price_per_room.describe()
# Out:
# count    36275.000000
# mean       103.423539
# std         35.089424
# min          0.000000
# 25%         80.300000
# 50%         99.450000
# 75%        120.000000
# max        540.000000
# Name: avg_price_per_room, dtype: float64

# %%
IQR_APPR=df.avg_price_per_room.quantile(0.75)-df.avg_price_per_room.quantile(0.25)
IQR_APPR
# Out:
# 39.7

# %%
u_b2=df["avg_price_per_room"].quantile(0.75)+(IQR_APPR*3)  
l_b2=df["avg_price_per_room"].quantile(0.75)-(IQR_APPR*3)  
print(u_b2)
print(l_b2)
# Out:
# 239.10000000000002
# 0.8999999999999915

# %%
df.loc[df["avg_price_per_room"]>239.10,"avg_price_per_room"]=239.10
df.loc[df["avg_price_per_room"]<0.899,"avg_price_per_room"]=0.899

# %%
sns.distplot(df.avg_price_per_room,bins=10)
plt.show()

# %%
df.avg_price_per_room.hist()
plt.show()

# %% [markdown]
# # SKEWNESS TREATMENT

# %%
df.skew()
# Out:
# no_of_adults                            -0.333295
# no_of_children                           4.710350
# no_of_weekend_nights                     0.737616
# no_of_week_nights                        1.062304
# type_of_meal_plan                        1.801398
# required_car_parking_space               5.413643
# room_type_reserved                       1.729018
# lead_time                                1.292492
# arrival_year                            -1.669695
# arrival_month                           -0.348229
# arrival_date                             0.028809
# market_segment_type                     -1.684871
# repeated_guest                           6.002888
# no_of_previous_cancellations            25.199876
# no_of_previous_bookings_not_canceled    19.250191
# avg_price_per_room                       0.512601
# no_of_special_requests                   1.145081
# booking_status                          -0.734507
# dtype: float64

# %%
df.lead_time.skew()
# Out:
# 1.2924915330710838

# %%
df["lead_time"]=np.sqrt(df["lead_time"])

# %%
df.lead_time.skew()
# Out:
# 0.32348753980863104

# %% [markdown]
# # Feature Selection

# %%
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()

# %%
rfe=RFE(dtree)

# %%
rfe.fit(X,Y)
# Out:
# RFE(estimator=DecisionTreeClassifier())

# %%
rfe.support_
# Out:
# array([False, False,  True,  True, False, False, False,  True, False,
#         True,  True,  True, False, False, False,  True,  True])

# %%
df.columns
# Out:
# Index(['no_of_adults', 'no_of_children', 'no_of_weekend_nights',
#        'no_of_week_nights', 'type_of_meal_plan', 'required_car_parking_space',
#        'room_type_reserved', 'lead_time', 'arrival_year', 'arrival_month',
#        'arrival_date', 'market_segment_type', 'repeated_guest',
#        'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled',
#        'avg_price_per_room', 'no_of_special_requests', 'booking_status'],
#       dtype='object')

# %%
rf_df=pd.DataFrame({"features":list(rfe.support_),"columns":list(X)})
rf_df
# Out:
#     features                               columns
# 0      False                          no_of_adults
# 1      False                        no_of_children
# 2       True                  no_of_weekend_nights
# 3       True                     no_of_week_nights
# 4      False                     type_of_meal_plan
# 5      False            required_car_parking_space
# 6      False                    room_type_reserved
# 7       True                             lead_time
# 8      False                          arrival_year
# 9       True                         arrival_month
# 10      True                          arrival_date
# 11      True                   market_segment_type
# 12     False                        repeated_guest
# 13     False          no_of_previous_cancellations
# 14     False  no_of_previous_bookings_not_canceled
# 15      True                    avg_price_per_room
# 16      True                no_of_special_requests

# %% [markdown]
# # ML Models after Feature Selection(RFE)

# %%
new_x= X.drop(['no_of_adults', 'no_of_children','type_of_meal_plan', 'required_car_parking_space',
       'room_type_reserved','arrival_year','repeated_guest',
       'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled'],axis=1)

# %%
x_tr1,x_te1,y_tr1,y_te1=train_test_split(new_x,Y,test_size=0.2,random_state=100)

# %%
x_tr1.shape,x_te1.shape,y_tr1.shape,y_te1.shape
# Out:
# ((29020, 8), (7255, 8), (29020,), (7255,))

# %% [markdown]
# ## 1. Logistic Regression

# %%
lg.fit(x_tr1,y_tr1)
# Out:
# LogisticRegression()

# %%
f_p=lg.predict(x_te1)
f_p
# Out:
# array([0, 1, 0, ..., 1, 0, 1])

# %%
flg_cf=confusion_matrix(f_p,y_te1)
flg_cf
# Out:
# array([[1423,  532],
#        [ 934, 4366]], dtype=int64)

# %%
flg_ac=flg_cf.diagonal().sum()/flg_cf.sum()*100
flg_ac
# Out:
# 79.79324603721571

# %%
print(classification_report(f_p,y_te1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.73      0.66      1955
#            1       0.89      0.82      0.86      5300
#
#     accuracy                           0.80      7255
#    macro avg       0.75      0.78      0.76      7255
# weighted avg       0.81      0.80      0.80      7255

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

f_lgr_precision = precision_score(y_te1,f_p)
print('Precisiom: %f' % f_lgr_precision)

# Recall :- tp / (tp+fn)

f_lgr_recall = recall_score(y_te1,f_p)
print('Recall: %f' % f_lgr_recall)

#f1 :- 2tp / (2tp + fp + fn)

f_lgr_f1 = f1_score(y_te1,f_p)
print('F1 score: %f' % f_lgr_f1)
# Out:
# Precisiom: 0.823774
# Recall: 0.891384
# F1 score: 0.856246

# %% [markdown]
# ## 2. Decision Tree

# %%
dt.fit(x_tr1,y_tr1)
# Out:
# DecisionTreeClassifier()

# %%
f_p1= dt.predict(x_te1)
f_p1
# Out:
# array([1, 1, 1, ..., 0, 1, 1])

# %%
f_dt_cf=confusion_matrix(f_p1,y_te1)
f_dt_cf
# Out:
# array([[1864,  477],
#        [ 493, 4421]], dtype=int64)

# %%
f_dt_ac=f_dt_cf.diagonal().sum()/f_dt_cf.sum()*100
f_dt_ac
# Out:
# 86.62991040661613

# %%
print(classification_report(f_p1,y_te1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.80      0.79      2341
#            1       0.90      0.90      0.90      4914
#
#     accuracy                           0.87      7255
#    macro avg       0.85      0.85      0.85      7255
# weighted avg       0.87      0.87      0.87      7255

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

f_dt_precision = precision_score(y_te1,f_p1)
print('Precisiom: %f' % f_dt_precision)

# Recall :- tp / (tp+fn)

f_dt_recall = recall_score(y_te1,f_p1)
print('Recall: %f' % f_dt_recall)

#f1 :- 2tp / (2tp + fp + fn)

f_dt_f1 = f1_score(y_te1,f_p1)
print('F1 score: %f' % f_dt_f1)
# Out:
# Precisiom: 0.899674
# Recall: 0.902613
# F1 score: 0.901141

# %% [markdown]
# ## 3. Random Forest

# %%
rf.fit(x_tr1,y_tr1)

# %%
f_p2 = rf.predict(x_te1)
f_p2

# %%
f_rf_cf=confusion_matrix(f_p2,y_te1)
f_rf_cf

# %%
f_rf_ac=f_rf_cf.diagonal().sum()/f_rf_cf.sum()*100
f_rf_ac

# %%
print(classification_report(f_p2,y_te1))

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

f_rf_precision = precision_score(y_te1,f_p2)
print('Precisiom: %f' % f_rf_precision)

# Recall :- tp / (tp+fn)

f_rf_recall = recall_score(y_te1, f_p2)
print('Recall: %f' % f_rf_recall)

#f1 :- 2tp / (2tp + fp + fn)

f_rf_f1 = f1_score(y_te1,f_p2)
print('F1 score: %f' % f_rf_f1)

# %% [markdown]
# ## 4. KNN - K-Nearest Neighbor

# %%
knn.fit(x_tr1,y_tr1)

# %%
f_p3 = knn.predict(x_te1)
f_p3

# %%
f_knn_cf = confusion_matrix(f_p3,y_te1)
f_knn_cf

# %%
f_knn_ac = f_knn_cf.diagonal().sum()/f_knn_cf.sum()*100
f_knn_ac

# %%
print(classification_report(f_p3,y_te1))

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

f_knn_precision = precision_score(y_te1,f_p3)
print('Precisiom: %f' % f_knn_precision)

# Recall :- tp / (tp+fn)

f_knn_recall = recall_score(y_te1, f_p3)
print('Recall: %f' % f_knn_recall)

#f1 :- 2tp / (2tp + fp + fn)

f_knn_f1 = f1_score(y_te1,f_p3)
print('F1 score: %f' % f_knn_f1)

# %% [markdown]
# ## 5. Naive Bayes

# %%
nb.fit(x_tr1,y_tr1)

# %%
f_p4 = nb.predict(x_te1)
f_p4

# %%
f_nb_cf = confusion_matrix(f_p4,y_te1)
f_nb_cf

# %%
f_nb_ac = f_nb_cf.diagonal().sum()/f_nb_cf.sum()*100
f_nb_ac

# %%
print(classification_report(f_p4,y_te1))

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

f_nb_precision = precision_score(y_te1,f_p4)
print('Precisiom: %f' % f_nb_precision)

# Recall :- tp / (tp+fn)

f_nb_recall = recall_score(y_te1, f_p4)
print('Recall: %f' % f_nb_recall)

#f1 :- 2tp / (2tp + fp + fn)

f_nb_f1 = f1_score(y_te1,f_p4)
print('F1 score: %f' % f_nb_f1)

# %% [markdown]
# ## 6. XGBOOST

# %%
xgb.fit(x_tr1,y_tr1)

# %%
f_p6 = xgb.predict(x_te1)
f_p6

# %%
f_xgb_cf = confusion_matrix(f_p6,y_te1)
f_xgb_cf

# %%
f_xgb_ac = f_xgb_cf.diagonal().sum()/f_xgb_cf.sum()*100
f_xgb_ac

# %%
print(classification_report(f_p6,y_te1))

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

f_xgb_precision = precision_score(y_te1,f_p6)
print('Precisiom: %f' % f_xgb_precision)

# Recall :- tp / (tp+fn)

f_xgb_recall = recall_score(y_te1, f_p6)
print('Recall: %f' % f_xgb_recall)

#f1 :- 2tp / (2tp + fp + fn)

f_xgb_f1 = f1_score(y_te1,f_p6)
print('F1 score: %f' % f_xgb_f1)

# %% [markdown]
# # Accuracy of Base, Overssampled and Feature Selected Models

# %%
#Base model
l1 = {
    "Logistic_Regression":l_acc,
    "Decision_Tree":dt_acc,
    "Random_forest":rf_acc,
    "K-Nearest Neighbor":knn_acc,
    "Naive_Bayes":nb_acc,
    "XGBoost":xgb_acc
}

l2 = {
    "Logistic_Regression":blg_precision,
    "Decision_Tree":bdt_precision,
    "Random_forest":brf_precision,
    "K-Nearest Neighbor":bkn_precision,
    "Naive_Bayes":bnb_precision,
    "XGBoost":bxgb_precision
}

l3 = {
    "Logistic_Regression":blg_recall,
    "Decision_Tree":bdt_recall,
    "Random_forest":brf_recall,
    "K-Nearest Neighbor":bkn_recall,
    "Naive_Bayes":bnb_recall,
    "XGBoost":bxgb_recall
}

l4 = {
    "Logistic_Regression":blg_f1,
    "Decision_Tree":bdt_f1,
    "Random_forest":brf_f1 ,
    "K-Nearest Neighbor":bkn_f1,
    "Naive_Bayes":bnb_f1,
    "XGBoost":bxgb_f1

}

#IMB
li = {
    "Logistic_Regression":imb_ac,
    "Decision_Tree":idt_ac,
    "Random_forest":irf_ac,
    "K-Nearest Neighbor":iknn_ac,
    "Naive_Bayes":inb_ac,
    "XGBoost":ixgb_ac
}


li_1 = {
    "Logistic_Regression":ilg_precision,
    "Decision_Tree":idt_precision,
    "Random_forest":irf_precision,
    "K-Nearest Neighbor":iknn_precision,
    "Naive_Bayes":inb_precision,
    "XGBoost":ixgb_precision
}

li_2 = {
    "Logistic_Regression":ilg_recall,
    "Decision_Tree":idt_recall,
    "Random_forest":irf_recall,
    "K-Nearest Neighbor":iknn_recall,
    "Naive_Bayes":inb_recall,
    "XGBoost":ixgb_recall
}

li_3 = {
    "Logistic_Regression":ilg_f1,
    "Decision_Tree":idt_f1,
    "Random_forest":irf_f1,
    "K-Nearest Neighbor":iknn_f1,
    "Naive_Bayes":inb_f1,
    "XGBoost":ixgb_f1
}

#Final
l_1 = {
    "Logistic_Regression":flg_ac,
    "Decision_Tree":f_dt_ac,
    "Random_forest":f_rf_ac,
    "K-Nearest Neighbor":f_knn_ac,
    "Naive_Bayes":f_nb_ac,
    "XGBoost":f_xgb_ac
}

l_2 = {
    "Logistic_Regression":f_lgr_precision,
    "Decision_Tree":f_dt_precision,
    "Random_forest":f_rf_precision,
    "K-Nearest Neighbor":f_knn_recall,
    "Naive_Bayes":f_nb_precision,
    "XGBoost":f_xgb_precision
}

l_3 = {
    "Logistic_Regression":f_lgr_recall,
    "Decision_Tree":f_dt_recall,
    "Random_forest":f_rf_recall,
    "K-Nearest Neighbor":f_knn_recall,
    "Naive_Bayes":f_nb_recall,
    "XGBoost":f_xgb_recall
}

l_4 = {
    "Logistic_Regression":f_lgr_f1,
    "Decision_Tree":f_dt_f1,
    "Random_forest":f_rf_f1,
    "K-Nearest Neighbor":f_knn_f1,
    "Naive_Bayes":f_nb_f1,
    "XGBoost":f_xgb_f1
}

# %%
Final_model1 =pd.DataFrame({'Accuracy':l1, 'Precision':l2, 'Recall':l3, 'f1 score': l4})
Final_model1.style.set_caption("Base model metrics")

Final_model2 =pd.DataFrame({'Accuracy':li, 'Precision':li_1, 'Recall':li_2, 'f1 score': li_3})
Final_model2.style.set_caption("Oversampled model metrics")

Final_model3 =pd.DataFrame({'Accuracy':l_1, 'Precision':l_2, 'Recall':l_3, 'f1 score': l_4})
Final_model3.style.set_caption("Feature Selected RFE model metrics")

Final_model1, Final_model2, Final_model3

# %% [markdown]
# # Cross Validation(K-fold)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
import numpy as np

k=5
scores = cross_val_score(rf,x_te1,y_te1, cv=k, scoring='accuracy')

print("Cross Validation Scores:", scores)

mean_accuracy = np.mean(scores)
std_accuracy = np.std(scores)
print("Mean Accuracy:",mean_accuracy)
print("Standard Deviation of Accuracy:",std_accuracy)

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# Accuracy scores : The result of k-fold cross validation process indicate that the model consistently performs well across different parts of the dataset, with accuracy scores ranging from 0.8752 to 0.8862.
#
# Mean Accuracy: The mean accuracy is around 0.8815, represents the average performance of the model. It's simple yet powerful metric that indicates the model's reliability in making accurate predictions.
#
# Stability: The standard deviation of accuracy, approximately 0.0046, tells us that the model's performance remains stable across different folds of the data. This stability is like a safety net, ensuring that the model doesn't get swayed by variations in the training data.

# %% [markdown]
# Overall, these results suggest that the Random Forest classifier has a mean accuracy of around 88.16% with relatively low variance (as indicated by the low standard deviation). This means the model is performing consistently well on the different subsets of the data used in cross-validation.
